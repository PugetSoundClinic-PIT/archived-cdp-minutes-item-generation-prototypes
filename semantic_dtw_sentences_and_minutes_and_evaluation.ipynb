# %%
# !pip install cdp_data[transformers]
# !pip install python-docx
# !pip install pypdf2
# !pip install dtw-python
# !pip install fastdtw
# !pip install segeval
# !pip install 'fireo<2'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cdp_data[transformers]
#   Downloading cdp_data-0.0.9-py3-none-any.whl (815 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.7/815.7 KB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas~=1.0 in /usr/local/lib/python3.8/dist-packages (from cdp_data[transformers]) (1.3.5)
# Collecting dataclasses-json
#   Downloading dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.8/dist-packages (from cdp_data[transformers]) (1.22.4)
# Requirement already satisfied: nltk~=3.6 in /usr/local/lib/python3.8/dist-packages (from cdp_data[transformers]) (3.7)
# Collecting cdp-backend>=3.0.15
#   Downloading cdp_backend-4.0.7-py3-none-any.whl (51.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 MB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.63 in /usr/local/lib/python3.8/dist-packages (from cdp_data[transformers]) (4.64.1)
# Collecting gcsfs
#   Downloading gcsfs-2023.3.0-py2.py3-none-any.whl (26 kB)
# Collecting fireo
#   Downloading fireo-2.0.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 KB 1.5 MB/s eta 0:00:00
# Collecting sentence-transformers~=2.2.2
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting backoff>=2.2
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: google-cloud-firestore in /usr/local/lib/python3.8/dist-packages (from cdp-backend>=3.0.15->cdp_data[transformers]) (2.7.3)
# Requirement already satisfied: aiohttp>=3.8.1 in /usr/local/lib/python3.8/dist-packages (from cdp-backend>=3.0.15->cdp_data[transformers]) (3.8.4)
# Collecting fireo
#   Downloading fireo-1.7.0-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 KB 1.8 MB/s eta 0:00:00
# Collecting requests>=2.26.0
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from cdp-backend>=3.0.15->cdp_data[transformers]) (2023.1.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.8/dist-packages (from cdp-backend>=3.0.15->cdp_data[transformers]) (6.0)
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.8/dist-packages (from dataclasses-json->cdp_data[transformers]) (3.19.0)
# Collecting google-cloud-firestore
#   Downloading google_cloud_firestore-2.3.4-py2.py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.0/232.0 KB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.8/dist-packages (from gcsfs->cdp_data[transformers]) (4.4.2)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.8/dist-packages (from gcsfs->cdp_data[transformers]) (0.4.6)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.8/dist-packages (from gcsfs->cdp_data[transformers]) (2.16.1)
# Collecting fsspec
#   Downloading fsspec-2023.3.0-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 KB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.8/dist-packages (from gcsfs->cdp_data[transformers]) (2.7.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk~=3.6->cdp_data[transformers]) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk~=3.6->cdp_data[transformers]) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk~=3.6->cdp_data[transformers]) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas~=1.0->cdp_data[transformers]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas~=1.0->cdp_data[transformers]) (2022.7.1)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 44.0 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers~=2.2.2->cdp_data[transformers]) (1.13.1+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from sentence-transformers~=2.2.2->cdp_data[transformers]) (0.14.1+cu116)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from sentence-transformers~=2.2.2->cdp_data[transformers]) (1.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from sentence-transformers~=2.2.2->cdp_data[transformers]) (1.10.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.6 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp>=3.8.1->cdp-backend>=3.0.15->cdp_data[transformers]) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp>=3.8.1->cdp-backend>=3.0.15->cdp_data[transformers]) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp>=3.8.1->cdp-backend>=3.0.15->cdp_data[transformers]) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp>=3.8.1->cdp-backend>=3.0.15->cdp_data[transformers]) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp>=3.8.1->cdp-backend>=3.0.15->cdp_data[transformers]) (22.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp>=3.8.1->cdp-backend>=3.0.15->cdp_data[transformers]) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp>=3.8.1->cdp-backend>=3.0.15->cdp_data[transformers]) (1.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth>=1.2->gcsfs->cdp_data[transformers]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth>=1.2->gcsfs->cdp_data[transformers]) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth>=1.2->gcsfs->cdp_data[transformers]) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth>=1.2->gcsfs->cdp_data[transformers]) (1.15.0)
# Requirement already satisfied: google-api-core[grpc]<3.0.0dev,>=1.26.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-firestore->cdp-backend>=3.0.15->cdp_data[transformers]) (2.11.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from google-cloud-firestore->cdp-backend>=3.0.15->cdp_data[transformers]) (2.3.2)
# Requirement already satisfied: proto-plus>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-firestore->cdp-backend>=3.0.15->cdp_data[transformers]) (1.22.2)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.8/dist-packages (from google-cloud-firestore->cdp-backend>=3.0.15->cdp_data[transformers]) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers~=2.2.2->cdp_data[transformers]) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers~=2.2.2->cdp_data[transformers]) (3.9.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26.0->cdp-backend>=3.0.15->cdp_data[transformers]) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26.0->cdp-backend>=3.0.15->cdp_data[transformers]) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26.0->cdp-backend>=3.0.15->cdp_data[transformers]) (2022.12.7)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 54.2 MB/s eta 0:00:00
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib->gcsfs->cdp_data[transformers]) (1.3.1)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage->gcsfs->cdp_data[transformers]) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sentence-transformers~=2.2.2->cdp_data[transformers]) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->sentence-transformers~=2.2.2->cdp_data[transformers]) (8.4.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore->cdp-backend>=3.0.15->cdp_data[transformers]) (3.19.6)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore->cdp-backend>=3.0.15->cdp_data[transformers]) (1.58.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore->cdp-backend>=3.0.15->cdp_data[transformers]) (1.51.3)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore->cdp-backend>=3.0.15->cdp_data[transformers]) (1.48.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.8/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->gcsfs->cdp_data[transformers]) (1.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs->cdp_data[transformers]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs->cdp_data[transformers]) (3.2.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=d70eda0b2c350412b5bd71f4cd70ae290c4186b31da87e959d813e289c3a1b0d
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, requests, mypy-extensions, fsspec, backoff, typing-inspect, marshmallow-enum, huggingface-hub, transformers, dataclasses-json, sentence-transformers, google-cloud-firestore, gcsfs, fireo, cdp-backend, cdp_data
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.1.0
#     Uninstalling fsspec-2023.1.0:
#       Successfully uninstalled fsspec-2023.1.0
#   Attempting uninstall: google-cloud-firestore
#     Found existing installation: google-cloud-firestore 2.7.3
#     Uninstalling google-cloud-firestore-2.7.3:
#       Successfully uninstalled google-cloud-firestore-2.7.3
# Successfully installed backoff-2.2.1 cdp-backend-4.0.7 cdp_data-0.0.9 dataclasses-json-0.5.7 fireo-1.7.0 fsspec-2023.3.0 gcsfs-2023.3.0 google-cloud-firestore-2.3.4 huggingface-hub-0.12.1 marshmallow-enum-1.5.1 mypy-extensions-1.0.0 requests-2.28.2 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.26.1 typing-inspect-0.8.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 43.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from python-docx) (4.9.2)
# Building wheels for collected packages: python-docx
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184505 sha256=9f38ae525c02b4c6e68c5756ddd8c4b98b026edeb8e1b719da72342109cc8b28
#   Stored in directory: /root/.cache/pip/wheels/32/b8/b2/c4c2b95765e615fe139b0b17b5ea7c0e1b6519b0a9ec8fb34d
# Successfully built python-docx
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.11
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pypdf2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 KB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /usr/local/lib/python3.8/dist-packages (from pypdf2) (4.5.0)
# Installing collected packages: pypdf2
# Successfully installed pypdf2-3.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dtw-python
#   Downloading dtw_python-1.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.4/661.4 KB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.8/dist-packages (from dtw-python) (1.10.1)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.8/dist-packages (from dtw-python) (1.22.4)
# Installing collected packages: dtw-python
# Successfully installed dtw-python-1.3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fastdtw in /usr/local/lib/python3.8/dist-packages (0.3.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from fastdtw) (1.22.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segeval
#   Downloading segeval-2.0.11.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: segeval
#   Building wheel for segeval (setup.py) ... done
#   Created wheel for segeval: filename=segeval-2.0.11-py3-none-any.whl size=60283 sha256=5c4f7247699fb3de153faedb6f80134807702d8d742c0c278129db1b7522f3f9
#   Stored in directory: /root/.cache/pip/wheels/1c/76/82/8046697422e0382be4628c500ecb823edc998d47ad63294170
# Successfully built segeval
# Installing collected packages: segeval
# Successfully installed segeval-2.0.11
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fireo<2 in /usr/local/lib/python3.8/dist-packages (1.7.0)
# Requirement already satisfied: google-cloud-firestore<=2.3.4,>=2.2.0 in /usr/local/lib/python3.8/dist-packages (from fireo<2) (2.3.4)
# Requirement already satisfied: google-api-core[grpc]<3.0.0dev,>=1.26.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (2.11.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (2.3.2)
# Requirement already satisfied: proto-plus>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (1.22.2)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.8/dist-packages (from google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (23.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (1.58.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (2.28.2)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (2.16.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (3.19.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (1.51.3)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (4.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (1.26.14)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core[grpc]<3.0.0dev,>=1.26.0->google-cloud-firestore<=2.3.4,>=2.2.0->fireo<2) (0.4.8)

# %%
from cdp_data import CDPInstances, datasets

sessions_df = datasets.get_session_dataset(
    CDPInstances.Seattle,
    start_datetime="2022-08-19",
    end_datetime="2022-08-20",
    store_transcript=True,
    store_transcript_as_csv=True,
    replace_py_objects=True,
)
sessions_df
# Out:
# Fetching each model attached to event_ref:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching transcripts:   0%|          | 0/1 [00:00<?, ?it/s]
# Converting and storing each transcript as a CSV: 1it [00:01,  1.90s/it]
#            session_datetime  session_index  \
# 0 2022-08-19 16:30:00+00:00              0
#
#                                 session_content_hash  \
# 0  530ee1088e6d508ae79121837ff3bd9fea20e431095b80...
#
#                                            video_uri video_start_time  \
# 0  https://video.seattle.gov/media/council/sust_0...             None
#
#   video_end_time                                        caption_uri  \
# 0           None  https://www.seattlechannel.org/documents/seatt...
#
#   external_source_id            id                   key  \
# 0               None  1127cefbdc0c  session/1127cefbdc0c
#
#                                      transcript_path  \
# 0  /content/cdp-datasets/cdp-seattle-21723dcf/eve...
#
#                               transcript_as_csv_path      event_id  \
# 0  /content/cdp-datasets/cdp-seattle-21723dcf/eve...  147572cf9970
#
#   transcript_id
# 0  8c57ed56075b

# %%
import pandas as pd

example_t_path = sessions_df.iloc[0].transcript_as_csv_path
example_e_id = sessions_df.iloc[0].event_id
example_t = pd.read_csv(example_t_path)
example_t
# Out:
#      index  confidence  start_time  end_time  \
# 0        0        0.97      14.848    14.981
# 1        1        0.97      14.981    24.224
# 2        2        0.97      24.224    28.094
# 3        3        0.97      28.094    33.433
# 4        4        0.97      33.433    34.067
# ..     ...         ...         ...       ...
# 450    450        0.97    3622.185  3630.893
# 451    451        0.97    3630.893  3641.537
# 452    452        0.97    3641.537  3644.007
# 453    453        0.97    3644.007  3648.244
# 454    454        0.97    3648.244  3648.678
#
#                                                   text  speaker_index  \
# 0                                                    .              0
# 1    This is the regularly scheduled meeting of the...              1
# 2    I'm the chair of the Councilmember Kshama Sawant.              1
# 3                Would the clerk please call the roll?              1
# 4                         Councilmember Kshama Sawant.              2
# ..                                                 ...            ...
# 450  If there is no objection, the rule will be sus...             90
# 451  Seeing no objection, this resolution will be u...             90
# 452               Any further comments Councilmembers?             90
# 453  Seeing none, thank you all and the meeting is ...             90
# 454                                Take care, Bye Bye.             90
#
#      speaker_name  annotations
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ..            ...          ...
# 450           NaN          NaN
# 451           NaN          NaN
# 452           NaN          NaN
# 453           NaN          NaN
# 454           NaN          NaN
#
# [455 rows x 8 columns]

# %%
from cdp_backend.utils.file_utils import resource_copy
import docx
from pathlib import Path
from uuid import uuid4
from PyPDF2 import PdfReader
from sentence_transformers import SentenceTransformer
from cdp_data import CDPInstances
from cdp_data.utils import connect_to_infrastructure
from cdp_backend.database import models as db_models
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
import numpy as np
from fastdtw import fastdtw
from scipy.spatial.distance import cosine

def process_document(doc_path):
    # Try docx
    try:
        doc = docx.Document(doc_path)
        texts = []
        for para in doc.paragraphs:
            this_text = para.text.strip()
            if len(this_text) > 0:
                texts.append(this_text)

        # If we found text
        # This was a docx file
        if len(texts) > 0:
            return texts

        # If we didn't find text, it was still a docx file
        # that we just failed to parse
        # No need to try anything else in that case, just return
        return None

    # Try pdf
    except:
        try:
            reader = PdfReader(doc_path)
            texts = []
            for page in reader.pages:
                this_page_text = page.extract_text().strip()
                for para in this_page_text.split("\n"):
                    para_cleaned = para.strip()
                    if len(para_cleaned) > 0:
                        texts.append(para_cleaned)
            
            # If we found text
            # This was a pdf file
            if len(texts) > 0:
                return texts

            # If we didn't find text, it was still a pdf file
            # That we just failed to parse
            return None
        
        # It wasn't either file format
        except:
            return None

def process_file(file_model):
    try:
        # Create temp store path
        temp_store_path = Path(f"temp_{uuid4()}")

        # Store remote to local
        temp_store_path = Path(
            resource_copy(file_model.uri, dst=temp_store_path, overwrite=True),
        )

        # Get document content
        texts = process_document(temp_store_path)

        # Handle file not supported
        if texts is None:
            return None

        # Otherwise proceed
        # Encode all texts and then get the average vector
        model = SentenceTransformer("all-mpnet-base-v2")
        return model.encode(texts).mean(axis=0)
    
    # Always clear file
    finally:
        temp_store_path.unlink(missing_ok=True)

def evas_base_segmentation_alg(event_id, example_t):

  # Ignore resource copy warnings
  import warnings
  warnings.filterwarnings("ignore", message=".*Unverified HTTPS request is being made to host.*")

  # Connect to seattle
  connect_to_infrastructure(CDPInstances.Seattle)

  # Load model
  model = SentenceTransformer("all-mpnet-base-v2")

  # Pull event minutes items
  emis = list(
      db_models.EventMinutesItem.collection.filter(
          "event_ref", "==", f"{db_models.Event.collection_name}/{event_id}"
      ).order("index").fetch()
  )

  # Process event minutes items
  processed_emis = []
  for emi in tqdm(emis):
      # Encode the minutes item name
      mi = emi.minutes_item_ref.get()
      full_mi_name = mi.name
      if mi.description is not None:
          full_mi_name = f"{full_mi_name} {mi.description}"
    
      name_vec = model.encode([full_mi_name])[0]

      # Encode all supporting docs (if there are any)
      files = list(db_models.EventMinutesItemFile.collection.filter("event_minutes_item_ref", "==", emi.key).fetch())
      file_vecs = []
      for file_model in files:
          vec_or_none = process_file(file_model)
          if vec_or_none is not None:
              file_vecs.append(vec_or_none)
    
      # Average everything together
      emi_encoding = np.stack([name_vec, *file_vecs], axis=0).mean(axis=0)
      processed_emis.append({
          "vec": emi_encoding,
          "name": full_mi_name,
          "index": emi.index,
      })
    
  processed_emis_just_vecs = [emi["vec"] for emi in processed_emis]

  windowed_sentences = (
      example_t.text.shift(2)
      + " " + example_t.text.shift(1)
      + " " + example_t.text
      + " " + example_t.text.shift(-1)
      + " " + example_t.text.shift(-2)
  )
  windowed_sentences = windowed_sentences.fillna("START OR END")
  # print(len(windowed_sentences))

  sentence_embeddings = model.encode(windowed_sentences)
  # print(len(sentence_embeddings))
  sentence_embeddings_list = sentence_embeddings.tolist()

  distance, path = fastdtw(sentence_embeddings_list, processed_emis_just_vecs, dist=cosine)

  # print(distance)
  # print(len(path))

  example_t["minutes_item"] = [
    processed_emis[minute_index]["name"] for _, minute_index in path
  ]
  example_t
  # print(len(example_t))

  example_t.to_csv("dtw-transcript_" + str(event_id) + ".csv", index=False)

  # from dtw import dtw

  # result = dtw(
      # sentence_embeddings_list,
      # processed_emis_just_vecs,
      # dist_method="cosine",
  # )
  # result.plot()
  # return result.index2
  return [t[1] for t in path]

# %%
example_e_id
# Out:
# '147572cf9970'

# %%
eva_segmentation_147572cf9970 = evas_base_segmentation_alg(example_e_id, example_t)
# Out:
# 100%|██████████| 5/5 [01:27<00:00, 17.54s/it]

# %%
import segeval
import json

# convert to mass
my_list = segeval.convert_positions_to_masses(eva_segmentation_147572cf9970)

# Built JSON format
event_id = example_e_id
segmentation_type = "linear"

# create a dictionary with the event ID and segmentation list
event_dict = {event_id: my_list}

# create a dictionary with the "segmentations" key and the event dictionary
segmentations_dict = {"segmentations": event_dict}

# create a dictionary with the "items" key and the segmentations dictionary, and segmentation type
json_dict = {"items": segmentations_dict, "segmentation_type": segmentation_type}

# convert the dictionary to a JSON string and print it
json_str = json.dumps(json_dict, indent=4)
print(json_str)

# Writing to sample.json
with open("Eva_segmentations_" + str(event_id) + ".json", "w") as outfile:
    outfile.write(json_str)
# Out:
# {
#     "items": {
#         "segmentations": {
#             "147572cf9970": [
#                 1,
#                 18,
#                 10,
#                 418,
#                 8
#             ]
#         }
#     },
#     "segmentation_type": "linear"
# }

# %%
dataset_Eva = segeval.input_linear_mass_json('Eva_segmentations.json')
dataset_manual = segeval.input_linear_mass_json('manual_segmentations.json')

table_data = []

event_ids = set(dataset_Eva['segmentations'].keys()) & set(dataset_manual['segmentations'].keys())

i = 0
while i < len(event_ids):
    event_id = list(event_ids)[i]
    segmentation1 = dataset_Eva['segmentations'][event_id]
    segmentation2 = dataset_manual['segmentations'][event_id]
    similarity = segeval.boundary_similarity(segmentation1, segmentation2)
    table_data.append({'alg_name': 'evas_base_alg', 'event_id': event_id, 'segmentation_similarity': similarity})
    i += 1

# Define the table header
header = '| {:<15} | {:<20} | {:<25} |'.format('alg_name', 'event_id', 'segmentation_similarity')

# Print the table header
print('-' * len(header))
print(header)
print('-' * len(header))

# Print the table rows
for row in table_data:
    row_str = '| {:<15} | {:<20} | {:<25} |'.format(row['alg_name'], row['event_id'], row['segmentation_similarity'])
    print(row_str)
    print('-' * len(header))
# Out:
# ----------------------------------------------------------------------
# | alg_name        | event_id             | segmentation_similarity   |
# ----------------------------------------------------------------------
# | evas_base_alg   | 9a0564aaccbc         | 0.03846153846153846153846153846 |
# ----------------------------------------------------------------------
# | evas_base_alg   | 8dd03d0c3da8         | 0.1666666666666666666666666667 |
# ----------------------------------------------------------------------
# | evas_base_alg   | 6d0643d86325         | 0.02941176470588235294117647059 |
# ----------------------------------------------------------------------
# | evas_base_alg   | d6bb582ba073         | 0.1086956521739130434782608696 |
# ----------------------------------------------------------------------
# | evas_base_alg   | c5a6c08c7135         | 0                         |
# ----------------------------------------------------------------------
# | evas_base_alg   | 2f36715f7d1e         | 0                         |
# ----------------------------------------------------------------------
# | evas_base_alg   | 4175e4351ee9         | 0.1046511627906976744186046512 |
# ----------------------------------------------------------------------
# | evas_base_alg   | c0e331759993         | 0.2222222222222222222222222222 |
# ----------------------------------------------------------------------
# | evas_base_alg   | 5929a705b6aa         | 0                         |
# ----------------------------------------------------------------------
# | evas_base_alg   | 617e368b593d         | 0.1818181818181818181818181818 |
# ----------------------------------------------------------------------
# | evas_base_alg   | 3af736c4f8db         | 0.25                      |
# ----------------------------------------------------------------------
# | evas_base_alg   | e58393cb1ca2         | 0.1296296296296296296296296296 |
# ----------------------------------------------------------------------
# | evas_base_alg   | 28e4b5a48a20         | 0.25                      |
# ----------------------------------------------------------------------
# | evas_base_alg   | 8e5c03916399         | 0.04545454545454545454545454545 |
# ----------------------------------------------------------------------
# | evas_base_alg   | e92d77c71364         | 0.1875                    |
# ----------------------------------------------------------------------
# | evas_base_alg   | 66d084f9f0e5         | 0.06666666666666666666666666667 |
# ----------------------------------------------------------------------
# | evas_base_alg   | 401142a3eed9         | 0                         |
# ----------------------------------------------------------------------
# | evas_base_alg   | c688bfa2c288         | 0.2222222222222222222222222222 |
# ----------------------------------------------------------------------
# | evas_base_alg   | 957c62d3c8ce         | 0.1842105263157894736842105263 |
# ----------------------------------------------------------------------
# | evas_base_alg   | 7dd53cf3cdf4         | 0.1904761904761904761904761905 |
# ----------------------------------------------------------------------
# | evas_base_alg   | b7eca1d80332         | 0                         |
# ----------------------------------------------------------------------
# | evas_base_alg   | 147572cf9970         | 0.07142857142857142857142857143 |
# ----------------------------------------------------------------------
# | evas_base_alg   | 191da1d7a5c1         | 0.35                      |
# ----------------------------------------------------------------------
# | evas_base_alg   | 292bd698ea59         | 0                         |
# ----------------------------------------------------------------------
# | evas_base_alg   | 72697ba96a55         | 0.1153846153846153846153846154 |
# ----------------------------------------------------------------------
# | evas_base_alg   | 9fc814005fc0         | 0.05555555555555555555555555556 |
# ----------------------------------------------------------------------

# %%
# Define the data for the table as a list of dictionaries
table_data = [
    {'alg_name': 'evas_base_alg', 'event_id': '191da1d7a5c1', 'segmentation_similarity': segeval.boundary_similarity(segmentation1, segmentation2)},
    {'alg_name': 'evas_base_alg', 'event_id': '617e368b593d', 'segmentation_similarity': segeval.boundary_similarity(segmentation3, segmentation4)},
]

# Define the table header
header = '| {:<15} | {:<20} | {:<25} |'.format('alg_name', 'event_id', 'segmentation_similarity')

# Print the table header
print('-' * len(header))
print(header)
print('-' * len(header))

# Print the table rows
for row in table_data:
    row_str = '| {:<15} | {:<20} | {:<25} |'.format(row['alg_name'], row['event_id'], row['segmentation_similarity'])
    print(row_str)
    print('-' * len(header))
# Out:
# ----------------------------------------------------------------------
# | alg_name        | event_id             | segmentation_similarity   |
# ----------------------------------------------------------------------
# | evas_base_alg   | 191da1d7a5c1         | 0.35                      |
# ----------------------------------------------------------------------
# | evas_base_alg   | 191da1d7a5c1         | 0.1818181818181818181818181818 |
# ----------------------------------------------------------------------
